# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
X1 = np.arange(10,150,10)

Y1 = np.array([329.1,376.9,411.4,425.0,487.9,527.3,589.0,581.2,655.9,656.7,662.0,645.8,633.1,693.0])
Y2 = np.array([312.7,363.6,359.0,372.4,413.5,460.2,488.0,516.6,542.9,570.7,553.9,589.4,601.5,619.8])
Y3 = np.array([260.8,421.3,395.7,483.6,454.2,478.3,480.9,455.3,572.3,570.0,544.3,657.3,632.0,580.7])

plt.plot(X1, Y1,'-o',label='SPPL')
plt.plot(X1, Y2,'-p',label='MAM')
#plt.plot(X1, Y3,'-v',label='DMAM')

plt.xlabel("the number of sheep")
plt.ylabel("total steps")
plt.legend()
plt.grid()
plt.xticks(np.arange(10,150,10))
plt.show()
fig.savefig('mix.pdf',dpi=600,format='pdf')

# %%
A = np.mean(Y1)
B = np.mean(Y2)
C = np.mean(Y3)
print(A)
print(B)
print(C)
print((A-B)/A)
print((A-C)/A)
print((C-B)/B)
# Out:
# 548.1642857142857
# 483.15714285714284
# 499.05000000000007
# 0.11859062064292511
# 0.08959774832883768
# 0.03289376422932514

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
X1 = np.arange(5,150,5)

Y1 = np.array([663,639,945,554,1014,971,540,496,458,686,805,1255,1193,1095,1072,1042,1171,1159,991,867,1206,1394,1563,1316,1425,1561,1629,1238,1929])
Y2 = np.array([498,521,477,576,458,611,600,617,461,495,517,585,725,687,605,627,721,691,730,647,735,710,776,791,788,760,924,982,918])
Y3 = np.array([502,417,444,533,435,467,494,447,497,530,560,575,610,589,596,636,745,725,666,706,694,771,745,762,801,819,735,749,832])

plt.plot(X1, Y1,'-o',label='SPPL')
plt.plot(X1, Y2,'-p',label='MAM')
plt.plot(X1, Y3,'-v',label='DMAM')

plt.xlabel("the number of sheep")
plt.ylabel("total steps")
plt.legend()
plt.grid()
plt.xticks(np.arange(5,150,10))
plt.show()
fig.savefig('mix.pdf',dpi=600,format='pdf')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
X1 = np.arange(10,150,10)
Y1 = np.array([894,824,884,731,654,1229,1208,1219,1329,1030,1886,1864,2030,1376])
Y2 = np.array([545,550,583,568,490,531,672,847,667,644,796,883,813,1038])
Y3 = np.array([435,523,493,463,558,573,638,541,683,753,748,778,780,781])

plt.plot(X1, Y1,'-o',label='SPPL')
plt.plot(X1, Y2,'-p',label='MAM')
plt.plot(X1, Y3,'-v',label='DMAM')

plt.xlabel("the number of sheep")
plt.ylabel("total steps")
plt.legend()
plt.grid()

plt.show()

# %%
## 计算Ra的最佳值
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

X1 = np.arange(6, 20, 2)

Y0 = np.array([731,416,350,310,293,299,309])
Y1 = np.array([654,505,395,361,329,314,307])
Y2 = np.array([1229,945,596,538,497,496,495])
Y3 = np.array([1208,957,739,622,604,551,545])
#Y4 = np.array([1219,878,506,469,535,521,549])
#Y5 = np.array([1329,667,594,459,434,432,480])
Y6 = np.array([1030,723,535,457,435,432,529])

plt.plot(X1, Y0,'-o', label='$N=40$')
plt.plot(X1, Y1,'-o', label='$N=50$')
plt.plot(X1, Y2,'-o', label='$N=60$')
plt.plot(X1, Y3,'-o', label='$N=70$')
#plt.plot(X1, Y4,'-o', label='$N=80$')
#plt.plot(X1, Y5,'-o', label='$N=90$')
plt.plot(X1, Y6,'-o', label='$N=100$')


plt.xlabel("sheep to sheep interaction distance")
plt.ylabel("total steps")
plt.legend()
plt.grid()
plt.show()
fig.savefig('interaction.pdf',dpi=600,format='pdf')

# %%
# Ra = 6
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
X1 = np.arange(5,150,5)
Y1 = np.array([581,894,693,824,677,884,723,731,439,654,1124,1229,1299,1208,1261,1219,1225,1329,950,1030,1224,1886,1377,1864,1421,2030,1970,1376,1718])
Y2 = np.array([651,545,494,550,529,583,653,568,498,490,522,531,764,672,659,847,673,667,693,644,811,796,736,883,787,813,996,1038,886])
Y3 = np.array([546,435,444,523,454,493,500,463,514,558,531,573,649,638,608,541,675,683,705,753,730,748,771,778,806,780,730,781,856])

plt.plot(X1, Y1,'-o',label='SPPL')
plt.plot(X1, Y2,'-p',label='MAM')
plt.plot(X1, Y3,'-v',label='DMAM')

plt.xlabel("the number of sheep")
plt.ylabel("total steps")
plt.legend()
plt.grid()
plt.xticks(np.arange(5,150,10))
plt.show()
fig.savefig('mix.pdf',dpi=600,format='pdf')

# %%
# Ra = 10
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
X1 = np.arange(5,150,5)
#Y1 = np.array([388,303,298,405,407,396,353,350,356,395,504,596,531,739,498,506,533,594,524,535,617,675,689,700,659,589,589,630,797])
Y2 = np.array([318,317,306,339,329,382,372,360,350,365,393,383,487,484,454,449,445,465,464,461,469,502,499,517,527,536,541,584,572])
Y3 = np.array([284,294,283,341,317,329,347,363,361,399,426,412,446,459,461,445,485,487,470,484,505,501,525,519,512,561,540,556,544])

#plt.plot(X1, Y1,'-o',label='SPPL')
plt.plot(X1, Y2,'-p',label='MAM')
plt.plot(X1, Y3,'-v',label='DMAM')

plt.xlabel("the number of sheep")
plt.ylabel("total steps")
plt.legend()
plt.grid()
plt.xticks(np.arange(5,150,10))
plt.show()
fig.savefig('MAMvsDMAM.pdf',dpi=600,format='pdf')

# %%
A = np.mean(Y1)
B = np.mean(Y2)
C = np.mean(Y3)
print(A)
print(B)
print(C)
print((A-B)/A)
print((A-C)/A)
print((B-C)/B)
# Out:
# 522.6206896551724
# 436.8965517241379
# 436.41379310344826
# 0.16402744787542897
# 0.16495117445236218
# 0.001104972375690599

# %%
A = np.mean(Y1[9:])
B = np.mean(Y2[9:])

print(A)
print(B)

print((A-B)/A)
# Out:
# 595.0
# 479.85
# 0.19352941176470584

# %%
B = np.mean(Y2)
C = np.mean(Y3)

print(B)
print(C)
print((B-C)/B)
# Out:
# 436.8965517241379
# 436.41379310344826
# 0.001104972375690599
