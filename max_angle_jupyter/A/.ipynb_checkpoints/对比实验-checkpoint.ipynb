# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'
import matplotlib.pyplot as plt
import numpy as np
X1=np.array([30,35,40,45,50,55,60,65,70,75])
Y1=np.array([595,569,824,773,773,956,682,831,1595,1283])
Y2=np.array([352,518,636,526,498,911,445,1338 ,880 ,776])
plt.plot(X1,Y1,'g',label='original')
plt.plot(X1,Y2,'b',label='improved')
plt.xlabel("N Sheeps")
plt.ylabel("Total Steps")
plt.title("Sheeps Influence")
plt.legend()
plt.show()
plt.savefig('result.svg')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
X1=np.arange(30,60,2)
Y1=np.array([528,467,683,658,604,804,795,578,846,815,695,633,709,3001,3001])
Y2=np.array([487,454,564,586,569,543,543,615,525,649,605,1026,801,670,1849])
plt.plot(X1,Y1,'g--',label='original')
plt.plot(X1,Y2,'b-o',label='improved')
plt.xlabel("N Sheeps")
plt.ylabel("Total Steps")
plt.title("Sheeps Influence")
plt.legend()
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
X1=np.arange(20,50)
Y1=np.array([758,768,804,805,869,695,774,726,720,792,685,637,685,746,625,815,734,803,558,587,779,554,777,759,775,740,850,675,817,612])
Y2=np.array([971,815,1291,1627,659,605,642,633,649,647,683,621,640,657,651,632,613,648,668,645,646,656,652,660,652,661,666,655,662,644])
plt.plot(X1,Y1,'c-^',label='original')
plt.plot(X1,Y2,'b-o',label='improved')
plt.xlabel("no. neighbors")
plt.ylabel("total steps")
plt.title("k neighbors influence")
plt.legend()
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
X1=np.arange(40,80,2)
Y1=np.array([665,747,908,793,981,921,755,669,734,648,804,775,811,772,791,714,823,817,918,1018])
Y2=np.array([624,739,613,616,661,597,677,632,867,645,657,678,726,726,726,774,804,764,917,842])
plt.plot(X1,Y1,'m-D',label='original')
plt.plot(X1,Y2,'b-o',label='improved')
plt.xlabel("approach distances")
plt.ylabel("total steps")
plt.title("approach distance influence")
plt.legend()
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
X1=np.arange(20,100)
Y1=np.array([418,340,516,410,462,466,485,497,545,518,585,522,602,554,565,751,760,660,681,746,
             754,859,777,763,862,659,753,884,704,805,872,884,939,872,1031,684,870,855,946,969,
             984,950,1274,1097,926,1067,933,1221,1158,967,1206,946,1142,1206,1363,1058,1095,953,
             1098,1008,1155,1242,1099,1289,1184,1140,1078,1233,1187,1075,1285,1114,1275,1217,1304,
             1436,1457,1419,1367,1334])

Y2=np.array([776,377,561,963,544,503,1003,472,409,593,1127,1068,771,851,1264,1050,1470,953,1454,
             710,685,1066,842,1040,691,1310,647,684,923,772,982,835,980,1350,808,1179,1211,1715,
             1562,1167,1320,1378,1379,1495,1460,1233,989,899,1227,1256,1016,832,1310,1047,1019,
             1306,880,996,1005,1165,1119,1353,1099,1336,1018,921,1485,1620,1127,1135,1033,1131,
             1253,1400,2130,1420,1186,1436,1337,1483])
plt.plot(X1,Y1,'g-D',label='original')
plt.plot(X1,Y2,'b-o',label='improved')
plt.xlabel("sheeps")
plt.ylabel("steps")
plt.legend()
plt.axis([20,100,200,2000])
plt.show()

# %%
Y2=np.array([560,953,713,577,491,611,994,1022,781,754,672,622,762,1393,633,978,1185,1085,987,808,
             757,844,1086,692,785,1392,1422,1367,866,1301,1175,1375,888,1397,1274,1325,645,1200,955,
             1027,1254,1192,1626,1823,1049,1012,1254,1074,879,804,855,1251,1156,957,1369,1209,1093,1405,
             1077,951,1189,1022,1187,1703,1275,1505,1266,1441,1765,1202,1136,1301,1282,975,1069,1425,1128,
             1939,1947,1304])
