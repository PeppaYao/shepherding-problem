# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

X1 = np.arange(3, 13)
Y0 = np.array([549,421,304,277,268,250,258,264,263,302])
Y1 = np.array([586,478,345,301,321,274,301,285,300,324])
Y2 = np.array([802,512,452,380,379,331,320,336,435,352])


plt.plot(X1, Y0,'-o', label='N=50')
plt.plot(X1, Y1,'-o', label='N=60')
plt.plot(X1, Y2,'-o', label='N=70')


plt.xlabel("sheep displacement per time step")
plt.ylabel("total steps")
plt.legend()
plt.grid()
plt.show()
fig.savefig('speed.pdf',dpi=600,format='pdf')

# %% [markdown]
# ## 羊与羊之间的距离

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

X1 = np.arange(200, 300, 5)
Y0 = np.array([506,478,479,461,480,415,399,395,399,389,387,393,382,389,390,406,418,415,462,467])
Y1 = np.array([470,438,431,395,387,412,366,358,346,342,331,347,341,363,365,354,394,399,396,405])
Y2 = np.array([452,507,478,444,374,405,387,401,348,376,345,411,373,350,354,420,386,405,421,402])


plt.plot(X1, Y0,'-o', label='ra=10')
plt.plot(X1, Y1,'-o', label='ra=12')
plt.plot(X1, Y2,'-o', label='ra=14')


plt.xlabel("sheep to sheep interaction distance")
plt.ylabel("total steps")
plt.legend()
plt.show()
fig.savefig('interaction.pdf',dpi=600,format='pdf')

# %% [markdown]
# ## 不同视野距离下羊与羊个体距离与总效率之间的关系

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

X1 = np.arange(6, 20, 2)
Y0 = np.array([279, 296, 334, 409, 560, 685, 1397])
Y1 = np.array([259, 265, 308, 366, 580, 814, 1004])
Y2 = np.array([272, 336, 422, 506, 611, 871, 921])
Y3 = np.array([251, 352, 406, 495, 602, 781, 1813])

plt.plot(X1, Y0,'-o', label='rs=210')
plt.plot(X1, Y1,'-o', label='rs=230')
plt.plot(X1, Y2,'-o', label='rs=250')
plt.plot(X1, Y3,'-o', label='rs=270')

plt.xlabel("sheep to sheep interaction distance")
plt.ylabel("total steps")
plt.legend()
plt.grid()
plt.show()
fig.savefig('interaction.pdf',dpi=600,format='pdf')

# %% [markdown]
# ## 多次聚类的时间间隔

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

X1 = np.arange(20, 90, 5)
Y0 = np.array([1071, 2102, 871, 1406, 559, 620, 834, 699, 662, 1592, 1680, 1620, 1770,1880])

plt.plot(X1, Y0,'g-o', label='SPPL')

plt.xlabel("step interval")
plt.ylabel("total steps")
plt.legend()
plt.grid()
plt.show()
fig.savefig('interval.pdf',dpi=600,format='pdf')

# %% [markdown]
# ## 一般情况SPPL和分群策略的对比实验

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

X1 = np.arange(20, 80, 5)
Y0 = np.array([452, 398, 372, 321, 297, 310, 374, 451, 611, 690, 729, 625])
Y1 = np.array([419, 436, 436, 470, 468, 458, 480, 539, 491, 638, 662, 577])


plt.plot(X1, Y0,'g-o', label='SPPL')
plt.plot(X1, Y1,'b-o', label='SUB')

plt.xlabel("the number of sheep")
plt.ylabel("total steps")
plt.legend()
plt.grid()
plt.show()
fig.savefig('generalsubgroup.pdf',dpi=600,format='pdf')

# %% [markdown]
# ## 特殊情况SPPL和分群策略的对比实验

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

X1 = np.arange(20, 90, 5)
Y0 = np.array([357, 428, 407, 388, 410, 512, 427, 497, 500, 516, 548, 599, 539, 561])
Y1 = np.array([393, 402, 403, 404, 421, 425, 430, 434, 446, 429, 441, 455, 451, 455])


plt.plot(X1, Y0,'g-o', label='SPPL')
plt.plot(X1, Y1,'b-o', label='SUB')


plt.xlabel("the number of sheep")
plt.ylabel("total steps")
plt.legend()
plt.grid()
plt.show()
fig.savefig('subgroup.pdf',dpi=600,format='pdf')

# %% [markdown]
# ## 牧羊犬视野距离的对比折线图

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

X1 = np.arange(200,300,5)
Y0 = np.array([539,542,495,509,511,464,459,491,480,477,441,424,436,424,438,484,530,479,493,513])
Y1 = np.array([636,478,469,451,468,484,394,422,443,404,452,418,408,429,455,442,402,438,449,473])
Y2 = np.array([452,507,478,444,374,405,387,401,348,376,345,411,373,350,354,420,386,405,421,402])
Y3 = np.array([534,408,393,351,346,363,306,306,308,296,304,296,295,309,298,309,317,331,306,319])

plt.plot(X1, Y0,'y-o',label='$N=80$')
plt.plot(X1, Y1,'b-o',label='$N=70$')
plt.plot(X1, Y2,'g-o',label='$N=60$')
plt.plot(X1, Y3,'r-o',label='$N=50$')

plt.xlabel("the shepherd vision distance")
plt.ylabel("total steps")
plt.legend()
plt.show()
fig.savefig('specific.pdf',dpi=600,format='pdf')

# %% [markdown]
# ## 聚集模式和驱赶模式的占比箱图

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

fig,axes = plt.subplots(1,1)

arr1 = np.array([0.4037940379403794,0.551440329218107,0.35127478753541075,0.38935574229691877,0.4696969696969697,0.5676691729323309,0.5018050541516246,0.5613382899628253,0.5519713261648745,0.5211267605633803,0.5625,0.5483870967741935,0.4971751412429379,0.5093167701863354,0.5434173669467787,0.5469483568075117,0.4988009592326139,0.46938775510204084,0.4854368932038835,0.48769574944071586,0.42630385487528344,0.4753747323340471,0.46595744680851064,0.39316239316239315])
arr2 = np.array([0.4625668449197861,0.5107913669064749,0.36024844720496896,0.41139240506329117,0.375,0.5703125,0.49635036496350365,0.47419354838709676,0.51985559566787,0.5520504731861199,0.5084269662921348,0.4447004608294931,0.4432809773123909,0.5035971223021583,0.4546979865771812,0.38484848484848483,0.5283018867924528,0.45652173913043476,0.4959083469721768,0.39487179487179486,0.4538606403013183,0.36447978793903246,0.4278523489932886,0.468503937007874])
arr3 = np.array([0.515625,0.5338983050847458,0.5311203319502075,0.48846153846153845,0.4509090909090909,0.5492424242424242,0.5036764705882353,0.5670498084291188,0.5054945054945055,0.5161290322580645,0.5335570469798657,0.5311475409836065,0.5183946488294314,0.5,0.49740932642487046,0.5614754098360656,0.5553319919517102,0.49645390070921985,0.4629080118694362,0.555327868852459,0.5034013605442177,0.5733855185909981,0.47544204322200395,0.437984496124031])
arr4 = np.array([0.5314685314685315,0.49206349206349204,0.5275862068965518,0.48984771573604063,0.5154639175257731,0.48394495412844035,0.47109826589595377,0.5319148936170213,0.49056603773584906,0.4815950920245399,0.49122807017543857,0.49591280653950953,0.5436681222707423,0.5,0.5342857142857143,0.541501976284585,0.4634146341463415,0.5132605304212169,0.49816326530612246,0.4939140811455847,0.4991497975708502,0.5053956834532374,0.48346456692913387,0.48511576626240355])

df = pd.DataFrame(arr2,columns=['SPPL'])
s2 = pd.Series(arr1)
s3 = pd.Series(arr3)
s4 = pd.Series(arr4)

df['AMAM'] = s2
df['LMAM'] = s3
df['RMAM'] = s4
color = dict(boxes='DarkGreen',whiskers='DarkOrange',medians='DarkBlue',caps='Gray')
df.plot.box(ylim=[0.3,0.6], color = color,ax = axes, )

plt.show()
fig.savefig('box.pdf',dpi=600,format='pdf')

# %%
import numpy as np
mean1 = np.mean(arr1)
mean2 = np.mean(arr2)
mean3 = np.mean(arr3)
mean4 = np.mean(arr4)
print(mean1)
print(mean2)
print(mean3)
print(mean4)
# Out:
# 0.49080570777416943
# 0.4609422511028886
# 0.5151594030139935
# 0.502667671745128
