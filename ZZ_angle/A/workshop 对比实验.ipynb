# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
X1 = np.arange(20,90,5)

Y1 = np.array([307,320,312,306,298,294,316,409,427,448,446,473,518,483])
#Y2 = np.array([306,333,327,305,302,303,347,485,670,824,645,659,890,924])
Y3 = np.array([303,309,321,295,290,281,304,338,453,543,635,466,675,642])
Y4 = np.array([289,277,313,400,328,330,346,361,358,429,524,543,662,750])

plt.plot(X1, Y1,'-o',label='AMAM')
#plt.plot(X1, Y2,'-o',label='SPPL')
plt.plot(X1, Y3,'-o',label='LMAM')
plt.plot(X1, Y4,'-o',label='RMAM')

plt.xlabel("the number of sheep")
plt.ylabel("total steps")
plt.legend()
plt.grid()
plt.show()
fig.savefig('threeType.pdf',dpi=600,format='pdf')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
X1 = np.arange(20,90,5)

Y1 = np.array([307,320,312,306,298,294,316,409,427,448,446,473,518,483])
Y2 = np.array([306,333,327,305,302,303,347,485,670,824,645,659,890,924])
#Y3 = np.array([303,309,321,295,290,281,304,338,453,543,635,466,675,642])
#Y4 = np.array([289,277,313,400,328,330,346,361,358,429,524,543,662,750])

plt.plot(X1, Y1,'-o',label='AMAM')
plt.plot(X1, Y2,'-o',label='SPPL')
#plt.plot(X1, Y3,'-o',label='LMAM')
#plt.plot(X1, Y4,'-o',label='RMAM')

plt.xlabel("the number of sheep")
plt.ylabel("total steps")
plt.legend()
plt.grid()
plt.show()
fig.savefig('SPPLvsMAM.pdf',dpi=600,format='pdf')

# %%
Y1 = np.array([307,320,312,306,298,294,316])
Y2 = np.array([306,333,327,305,302,303,347])
y1 = np.mean(Y1)
y2 = np.mean(Y2)
print(y2/y1)
# Out:
# 1.032512772875058

# %%
Y1 = np.array([409,427,448,446,473,518,483])
Y2 = np.array([485,670,824,645,659,890,924])
y1 = np.mean(Y1)
y2 = np.mean(Y2)
print(y2/y1)
# Out:
# 1.5908239700374531

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import spline
fig, ax = plt.subplots()
X1 = np.arange(20,90,5)

Y1 = np.array([0.32679738562091504,0.36936936936936937,0.3180428134556575,0.4852459016393443,0.5,0.43564356435643564,0.5187319884726225,0.422680412371134,0.4059701492537313,0.5036407766990292,0.3922480620155039,0.3566009104704097,0.41797752808988764,0.36904761904761907])
Y2 = np.array([0.3257328990228013,0.40625,0.3942307692307692,0.4542483660130719,0.4563758389261745,0.4931972789115646,0.4810126582278481,0.4449877750611247,0.49882903981264637,0.5558035714285714,0.5403587443946188,0.42283298097251587,0.4826254826254826,0.43478260869565216])
Y3 = np.array([0.33663366336633666,0.36245954692556637,0.4236760124610592,0.5084745762711864,0.4586206896551724,0.5266903914590747,0.555921052631579,0.4408284023668639,0.5033112582781457,0.46593001841620624,0.49291338582677163,0.3948497854077253,0.4474074074074074,0.46261682242990654])
Y4 = np.array([0.33217993079584773,0.3898916967509025,0.4696485623003195,0.4525,0.45426829268292684,0.43333333333333335,0.5057803468208093,0.49584487534626037,0.48324022346368717,0.5268065268065268,0.4866412213740458,0.49171270718232046,0.48942598187311176,0.5773333333333334])

plt.plot(X1,Y1, 'r-',label='MCA')
plt.plot(X1,Y2, 'b-',label='SPP')
plt.plot(X1,Y3, 'c-',label='LMCA')
plt.plot(X1,Y4, 'y-',label='RMCA')

plt.xlabel("no.agents($N$)")
plt.ylabel("proportion of time spent collecting")
plt.legend()
plt.show()
fig.savefig('proportion.pdf',dpi=600,format='pdf')

# %% [markdown]
# ## 拟合曲线

# %%
import matplotlib.pyplot as plt
import numpy as np
T = np.array([6, 7, 8, 9, 10, 11, 12,13])
power = np.array([6, 3, 2.5, 2, 2.5, 1.1, 1.5,1.4])
plt.plot(T, power)
plt.show()

spl = BSpline(T, power,3)
xx = np.linspace(T.min(), T.max(), 100)
plt.plot(xx, spl(xx), 'b-',label='BSpline')
plt.grid()
plt.show()

from scipy.interpolate import spline
xnew = np.linspace(T.min(),T.max(),300) #300 represents number of points to make between T.min and T.max
power_smooth = spline(T,power,xnew)
plt.plot(xnew,power_smooth)
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   app.launch_new_instance()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
X1 = np.arange(20,90)

Y1 = np.array([307,300,321,322,323,320,324,312,330,346,312,338,330,297,308,306,346,482,306,295,298,309,321,291,298,294,302,309,347,300,316,322,352,323,334,409,358,368,327,372,427,412,464,475,473,448,443,441,477,426,446,443,414,496,476,473,421,467,499,495,518,550,515,576,492,483,532,515,446,513])
Y2 = np.array([306,313,288,304,319,333,325,305,325,300,327,315,320,324,329,305,323,437,325,311,302,331,358,320,309,303,316,358,362,358,347,404,479,394,443,485,500,559,490,540,670,678,886,574,609,824,885,643,699,1167,645,705,935,666,683,659,658,756,688,654,890,695,669,648,747,924,649,775,829,1098])
Y3 = np.array([303,280,298,300,432,309,296,283,312,354,321,287,346,318,297,295,302,329,295,292,290,286,278,288,304,281,295,342,313,310,304,459,308,333,371,338,340,485,476,405,453,621,429,637,817,543,593,744,589,633,635,488,760,519,603,466,455,719,519,616,675,588,520,607,521,642,674,683,595,644])
Y4 = np.array([289,279,274,275,294,277,279,289,306,295,313,302,301,443,421,400,316,384,342,302,328,477,411,573,405,330,419,328,510,335,346,315,397,391,392,361,352,376,371,373,358,441,419,502,448,429,660,835,425,425,524,685,573,622,638,543,539,607,597,549,662,730,577,641,610,750,858,706,674,722])

plt.plot(X1, Y1,'r-^',label='MCA')
plt.plot(X1, Y2,'b-o',label='SPP')
plt.plot(X1, Y3,'c-*',label='LMCA')
plt.plot(X1, Y4,'y-d',label='RMCA')

plt.xlabel("no.agents($N$)")
plt.ylabel("total steps")
plt.legend()
plt.show()
fig.savefig('extensiveContrast.pdf',dpi=600,format='pdf')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import spline
fig, ax = plt.subplots()
X1 = np.arange(20,90,5)

Y1 = np.array([0.32679738562091504,0.36936936936936937,0.3180428134556575,0.4852459016393443,0.5,0.43564356435643564,0.5187319884726225,0.422680412371134,0.4059701492537313,0.5036407766990292,0.3922480620155039,0.3566009104704097,0.41797752808988764,0.36904761904761907])
Y2 = np.array([0.3257328990228013,0.40625,0.3942307692307692,0.4542483660130719,0.4563758389261745,0.4931972789115646,0.4810126582278481,0.4449877750611247,0.49882903981264637,0.5558035714285714,0.5403587443946188,0.42283298097251587,0.4826254826254826,0.43478260869565216])
Y3 = np.array([0.33663366336633666,0.36245954692556637,0.4236760124610592,0.5084745762711864,0.4586206896551724,0.5266903914590747,0.555921052631579,0.4408284023668639,0.5033112582781457,0.46593001841620624,0.49291338582677163,0.3948497854077253,0.4474074074074074,0.46261682242990654])
Y4 = np.array([0.33217993079584773,0.3898916967509025,0.4696485623003195,0.4525,0.45426829268292684,0.43333333333333335,0.5057803468208093,0.49584487534626037,0.48324022346368717,0.5268065268065268,0.4866412213740458,0.49171270718232046,0.48942598187311176,0.5773333333333334])

plt.plot(X1, Y1,'r-o',label='MCA')
plt.plot(X1, Y2,'b-^',label='SPP')
plt.plot(X1, Y3,'c-s',label='LMCA')
plt.plot(X1, Y4,'y-p',label='RMCA')

plt.xlabel("no.agents($N$)")
plt.ylabel("total steps")
plt.legend()
plt.show()
fig.savefig('proportion.pdf',dpi=600,format='pdf')

# %% [markdown]
# ## 步长为3的对比图

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


fig, ax = plt.subplots()
X1 = np.arange(20,90,3)

Y1 = np.array([307,322,324,346,330,306,306,309,298,309,316,323,358,372,464,448,477,443,476,467,518,576,532,513])
Y2 = np.array([306,304,325,300,320,305,325,331,309,358,347,394,500,540,886,824,699,705,683,756,890,648,649,1098])
#Y3 = np.array([303,300,296,354,346,295,295,286,304,342,304,333,340,405,429,543,589,488,603,719,675,607,674,644])
#Y4 = np.array([289,275,279,295,301,400,342,477,405,328,346,391,352,373,419,429,425,685,638,607,662,641,858,722])

plt.plot(X1, Y1,'-o',label='MAM')
plt.plot(X1, Y2,'-o',label='SPPL')
#plt.plot(X1, Y3,'-o',label='LMAM')
#plt.plot(X1, Y4,'-o',label='RMAM')

plt.xlabel("the number of sheep($N$)")
plt.ylabel("total steps")
plt.legend()
plt.show()
fig.savefig('newContrast.pdf',dpi=600,format='pdf')

# %% [markdown]
# ## 步长为3的聚集比例

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import spline
fig, ax = plt.subplots()
X1 = np.arange(20,90,3)

Y1 = np.array([0.3257328990228013,0.3416149068322981,0.3055555555555556,0.36416184971098264,0.4212121212121212,0.4542483660130719,0.4444444444444444,0.42071197411003236,0.4597315436241611,0.48220064724919093,0.4810126582278481,0.5108359133126935,0.4441340782122905,0.5618279569892473,0.5517241379310345,0.5558035714285714,0.5681341719077568,0.48081264108352145,0.47689075630252103,0.4817987152034261,0.4826254826254826,0.4427083333333333,0.4492481203007519,0.38596491228070173])
Y2 = np.array([0.32679738562091504,0.3618421052631579,0.3230769230769231,0.41,0.390625,0.4852459016393443,0.40923076923076923,0.5075528700906344,0.4692556634304207,0.5251396648044693,0.5187319884726225,0.44416243654822335,0.528,0.3925925925925926,0.46613995485327314,0.5036407766990292,0.4005722460658083,0.3843971631205674,0.3850658857979502,0.43915343915343913,0.41797752808988764,0.3487654320987654,0.4067796610169492,0.39799635701275043])
Y3 = np.array([0.33663366336633666,0.38666666666666666,0.4155405405405405,0.4463276836158192,0.42196531791907516,0.5084745762711864,0.5491525423728814,0.513986013986014,0.4605263157894737,0.49122807017543857,0.555921052631579,0.5645645645645646,0.4588235294117647,0.5654320987654321,0.5034965034965035,0.46593001841620624,0.466893039049236,0.45901639344262296,0.5024875621890548,0.5396383866481224,0.4474074074074074,0.4316309719934102,0.47774480712166173,0.4611801242236025])
Y4 = np.array([0.33217993079584773,0.4218181818181818,0.40860215053763443,0.46440677966101696,0.36212624584717606,0.4525,0.47368421052631576,0.4716981132075472,0.4419753086419753,0.5,0.5057803468208093,0.43478260869565216,0.4289772727272727,0.46648793565683644,0.45584725536992843,0.5268065268065268,0.4447058823529412,0.5094890510948905,0.5266457680250783,0.4497528830313015,0.48942598187311176,0.4539781591263651,0.5093240093240093,0.4930747922437673])

plt.plot(X1, Y1,'r-',label='MCA')
plt.plot(X1, Y2,'b--',label='SPP')
plt.plot(X1, Y3,'g:',label='LMCA')
plt.plot(X1, Y4,'y-.',label='RMCA')

plt.xlabel("no.agents($N$)")
plt.ylabel("proportion of time spent collecting")
plt.legend()
plt.show()
fig.savefig('proportion.pdf',dpi=600,format='pdf')

# %% [markdown]
# ## 牧羊犬视距影响

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

X1 = np.arange(100,750,50)
Y0 = np.array([1195,734,539,441,518,498,513,725,630,737,698,565,643])
Y1 = np.array([1125,593,636,452,446,567,512,624,626,571,673,554,570])
Y2 = np.array([891,591,452,345,427,465,528,518,527,518,521,567,481])
Y3 = np.array([846,465,534,304,316,348,364,397,461,441,457,482,440])

plt.plot(X1, Y0,'y-o',label='$N=80$')
plt.plot(X1, Y1,'b-o',label='$N=70$')
plt.plot(X1, Y2,'g-o',label='$N=60$')
plt.plot(X1, Y3,'r-o',label='$N=50$')

plt.xlabel("the shepherd vision distance")
plt.ylabel("total time steps")
plt.legend()
plt.grid()
plt.show()
fig.savefig('shepherdken.pdf',dpi=600,format='pdf')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

X1 = np.arange(200,300,5)
Y0 = np.array([452,507,478,444,374,405,387,401,348,376,345,411,373,350,354,420,386,405,421,402])
plt.plot(X1, Y0,'b-o',label='$N=60$')

plt.xlabel("the ken of shepherd")
plt.ylabel("total steps")
plt.legend()
plt.show()
fig.savefig('specificken.pdf',dpi=600,format='pdf')

# %% [markdown]
# ## knn最大值，均值，最小值对比图

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

X1 = np.arange(20,90,3)
Y1 = np.array([446,462,478,512,536,559,545,623,626,699,621,661,688,674,791,694,785,823,729,852,845,911,896,747])
Y2 = np.array([337.94,334.88,345.08,373.1,380.16,387.64,403.64,412.4,405.48,415.96,422.26,430.82,448.68,444.52,483.48,477.74,503.66,485.52,488.58,513.16,531.26,558.32,541.78,545.8])
Y3=np.array([262,256,270,273,246,269,297,291,285,299,324,316,327,324,342,357,398,377,377,412,412,405,390,436])

plt.plot(X1, Y1,'b-.',label='MAX')
plt.plot(X1, Y2,'g-',label='MEAN')
plt.plot(X1, Y3,'c--',label='MIN')

plt.xlabel("the number of sheep($N$)")
plt.ylabel("total steps")
plt.legend()
plt.show()
fig.savefig('mean.pdf',dpi=600,format='pdf')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

X1 = np.arange(20,90,3)
Y1 = np.array([452,486,470,494,479,501,486,568,574,545,535,588,630,717,672,863,639,656,682,704,823,718,630,705])
Y2 = np.array([302.2,340.62,335.32,338.78,364.62,362.32,343.86,370.82,368.34,392.84,367.28,391.3,398.02,416.52,415.26,460.54,450.22,461.4,473.52,484.72,496.88,509.16,503.6,532.66])
Y3=np.array([226,236,234,246,257,247,268,273,272,276,294,288,319,316,319,336,354,330,379,389,396,418,396,442])
Y4 = np.array([369,243,353,357,264,266,277,269,279,284,304,310,354,322,357,426,417,392,412,447,441,467,470,468])

plt.plot(X1, Y1,':',label='MAX')
plt.plot(X1, Y2,'-.',label='MEAN')
plt.plot(X1, Y3,'--',label='MIN')
plt.plot(X1, Y4,'-',label='AMAM')
plt.xlabel("the number of sheep($N$)")
plt.ylabel("total steps")
plt.legend()
plt.grid()
plt.show()
fig.savefig('mean.pdf',dpi=600,format='pdf')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

X1 = np.arange(20,90,3)
Y1 = np.array([373,240,363,352,273,249,281,267,273,279,302,302,361,368,353,395,424,420,450,471,502,460,550,648])
Y2 = np.array([369,243,353,357,264,266,277,269,279,284,304,310,354,322,357,426,417,392,412,447,441,467,470,468])

plt.plot(X1, Y1,'r-^',label='MCAs')
plt.plot(X1, Y2,'g-o',label='MCA')

plt.xlabel("no.agents($N$)")
plt.ylabel("total steps")
plt.legend()
plt.show()
fig.savefig('compare.pdf',dpi=600,format='pdf')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

X1 = np.arange(200,300,5)
Y0 = np.array([452,507,478,444,374,405,387,401,348,376,345,411,373,350,354,420,386,405,421,402])
plt.plot(X1, Y0,'b-o',label='$N=60$')

plt.xlabel("the ken of shepherd")
plt.ylabel("total steps")
plt.legend()
plt.show()
fig.savefig('specificken.pdf',dpi=600,format='pdf')

# %% [markdown]
# ## 最佳Rs的结果

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import spline

fig, ax = plt.subplots()
X1 = np.arange(20,90,3)

Y1 = np.array([369,243,353,357,264,266,277,269,279,284,304,310,354,322,357,426,417,392,412,447,441,467,470,468])
Y2 = np.array([374,278,322,316,312,256,274,310,277,317,356,434,573,417,596,660,530,644,611,780,531,1509,596,508])
Y3 = np.array([256,236,241,260,275,264,272,261,273,279,298,305,299,334,386,488,497,423,674,488,588,511,509,516])
Y4 = np.array([429,378,290,394,388,436,346,376,424,326,399,367,458,414,350,506,492,641,490,419,494,556,635,907])

plt.plot(X1, Y1,'r-o',label='MCA')
plt.plot(X1, Y2,'b-^',label='SPP')
plt.plot(X1, Y3,'c-s',label='LMCA')
plt.plot(X1, Y4,'y-p',label='RMCA')

plt.xlabel("no.agents($N$)")
plt.ylabel("total steps")
plt.legend()
plt.show()
fig.savefig('newContrast.pdf',dpi=600,format='pdf')

# %% [markdown]
# ## 考察频率的用直方图

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
data=np.array([5,6,2,3,5,9])
plt.hist(data, bins=5,facecolor="blue")
plt.show()

# %%
for i in range(200,300,10):
    print(i, end=",")
# Out:
# 200,210,220,230,240,250,260,270,280,290,

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig,axes = plt.subplots()
movie_name = [200,210,220,230,240,250,260,270,280,290]
y = [452,478,374,387,348,345,373,354,386,421]
x = range(len(movie_name))
plt.bar(x, y, width=0.5,color='blue',alpha=0.7)
plt.xticks(x, movie_name)
plt.ylim(200, 550)   
plt.show()
fig.savefig('bar.pdf',dpi=600,format='pdf')

# %%
import pandas as pd
u = np.array([[5,6],
              [3,6],
              [7,8]])
col = ['MCA collecting', 'SPP collecting']
df = pd.DataFrame(u,columns = col)
df
# Out:
#    MCA collecting  SPP collecting
# 0               5               6
# 1               3               6
# 2               7               8

# %%
arr = np.array([5,6,7,8])
arr1=np.array([5.6,8,0,9])
s1 = pd.Series(arr)
df = pd.DataFrame(arr,columns=['MCA'])
df['SPP'] = s2
df
# Out:
#    MCA  SPP
# 0    5  5.6
# 1    6  8.0
# 2    7  0.0
# 3    8  9.0

# %% [markdown]
# ## 箱图

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

fig,axes = plt.subplots(1,1)

arr1 = np.array([0.46715328467153283,0.3993808049535604,0.44370860927152317,0.6415094339622641,
                 0.5886287625418061,0.5290102389078498,0.4897360703812317,0.41647597254004576,0.42658730158730157,
                 0.3617391304347826,0.33104395604395603,0.391304347826087,0.3924611973392461,0.37280701754385964,0.3804573804573805])

arr2 = np.array([0.4664179104477612,0.4868913857677903,0.5209125475285171,0.5535714285714286,
                 0.5851063829787234,0.5294117647058824,0.5153203342618384,0.4770408163265306,0.4405594405594406,
                 0.42733188720173537,0.43201754385964913,0.4068181818181818,0.3881856540084388,0.3818565400843882,0.3799126637554585])

df = pd.DataFrame(arr1,columns=['SPPL'])
s2 = pd.Series(arr2)

df['MAM'] = s2
color = dict(boxes='DarkGreen',whiskers='DarkOrange',medians='DarkBlue',caps='Gray')
df.plot.box(ylim=[0.3,0.6], color = color,ax = axes)
plt.grid()
plt.show()
fig.savefig('box.pdf',dpi=600,format='pdf')

# %%
print(np.mean(arr1))
print(np.mean(arr2))
# Out:
# 0.4421335672308285
# 0.4660902987917177
