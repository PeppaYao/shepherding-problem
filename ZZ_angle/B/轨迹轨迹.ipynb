# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

x = np.arange(1,10)
y1 = x**2
y2 = x + 40
plt.plot(x, y1, linewidth=5)
plt.plot(x, y2, linewidth=0.5)

plt.legend()
plt.show()
#fig.savefig('trajectory.pdf',dpi=600,format='pdf')
# Out:
# No handles with labels found to put in legend.
